# %% [markdown]
# # OUTCOMES:
# y=mx+b
# m means weightage here
# x input
# b offset
# if there is no b , then
# if x is zero than whole will be zero , but it is not as it , thats why we have added b

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('placement.csv')
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
plt.scatter(df['cgpa'], df['package']) 
plt.xlabel("X")
plt.show()

# %%
x=df.iloc[:,0:1]
y=df.iloc[: ,-1]

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train, y_test= train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# C:\Users\haseeb\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.89111601])

# %%
# print(X_test )
# print("SERIOIS")
# print(y_test )

# %% [markdown]
# # SHOWING THE REAL VALUE AND EXPECTED

# %%
plt.scatter(df['cgpa'], df['package']) 
plt.plot(X_train, lr.predict(X_train), color='red')  # ✅ X_train must match dimensions
plt.xlabel("X")
plt.show()
